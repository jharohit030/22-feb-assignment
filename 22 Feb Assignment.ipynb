# %%
#Question1:
import pandas as pd
l= [4,8,15,16,23,42]
pd.Series(l)
# Out:
# 0     4
# 1     8
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
#Question2:

l = [2,4,5,6,23,43,54,65,34,10]
pd.Series(l)
# Out:
# 0     2
# 1     4
# 2     5
# 3     6
# 4    23
# 5    43
# 6    54
# 7    65
# 8    34
# 9    10
# dtype: int64

# %%
#Question 3:

df = pd.DataFrame({'Name':['Alice','Bob','Claire'],'Age':[25,30,27],'Gender':['Female','Male','Female']})

# %%
df
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %%
#Question 4:

A pandas DataFrame is a two-dimensional data structure that can be thought of as a spreadsheet. It can also be thought of as a collection of two or more series with common indices.
Example:
fruits_jack = ['apple','oranges','bananas']
fruits_john= ['guava','kiwis','strawberries']
index = ['a','b','c']
all_fruits = {'Jack':fruits_jack,'John':fruits_john}
df = pd.DataFrame(all_fruits, index = index)

# %%
df
# Out:
#       Jack          John
# a    apple         guava
# b  oranges         kiwis
# c  bananas  strawberries

# %%
A pandas series is a one-dimensional data structure that comprises of key-value pair, where keys/labels are the indices and values are the values stored on that index. It is similar to a python dictionary, except it provides more freedom to manipulate and edit the data.
Example:
fruits = pd.Series(['apple','oranges','bananas'])

# %%
fruits
# Out:
# 0      apple
# 1    oranges
# 2    bananas
# dtype: object

# %%
#Question 5:

df= pd.read_csv('output.csv')

# %%
df
# Out:
#        FinInstrmGnlAttrbts.Id         FinInstrmGnlAttrbts.FullNm  \
# 0                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 1                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 2                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 3                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 4                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# ...                       ...                                ...
# 141376           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141377           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141378           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141379           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141380           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
#
#        FinInstrmGnlAttrbts.ClssfctnTp  FinInstrmGnlAttrbts.CmmdtyDerivInd  \
# 0                              OPAIPS                               False
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#   FinInstrmGnlAttrbts.Id         FinInstrmGnlAttrbts.FullNm  \
# 0           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 1           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 2           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 3           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 4           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 5           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 6           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 7           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 8           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 9           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
#
#   FinInstrmGnlAttrbts.ClssfctnTp  FinInstrmGnlAttrbts.CmmdtyDerivInd  \
# 0                         OPAIPS                               False
# 1                         OPAIPS                               False
# 2                         OPAIPS                               False
# ...

# %%
df.tail(10)
# Out:
#        FinInstrmGnlAttrbts.Id         FinInstrmGnlAttrbts.FullNm  \
# 141371           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141372           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141373           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141374           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141375           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141376           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141377           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141378           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141379           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141380           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
#
#        FinInstrmGnlAttrbts.ClssfctnTp  FinInstrmGnlAttrbts.CmmdtyDerivInd  \
# 141371                         OPAIPS                               False
# 141372                         OPAIPS                               False
# ...

# %%
df.shape
# Out:
# (141381, 6)

# %%
df.describe()
# Out:
#        FinInstrmGnlAttrbts.Id         FinInstrmGnlAttrbts.FullNm  \
# count                  141381                             141381
# unique                      1                                  1
# top              DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# freq                   141381                             141381
#
#        FinInstrmGnlAttrbts.ClssfctnTp FinInstrmGnlAttrbts.CmmdtyDerivInd  \
# count                          141381                             141381
# unique                              1                                  1
# top                            OPAIPS                              False
# freq                           141381                             141381
#
#        FinInstrmGnlAttrbts.NtnlCcy                  Issr
# count                       141381                141381
# unique                           1                   271
# top                            USD  529900UT4DG0LG5R9O07
# ...

# %%
df.dropna()
# Out:
#        FinInstrmGnlAttrbts.Id         FinInstrmGnlAttrbts.FullNm  \
# 0                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 1                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 2                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 3                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 4                DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# ...                       ...                                ...
# 141376           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141377           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141378           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141379           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
# 141380           DE000C42LZJ8  OEMB SI 20210115 PS AM P 112.50 0
#
#        FinInstrmGnlAttrbts.ClssfctnTp  FinInstrmGnlAttrbts.CmmdtyDerivInd  \
# 0                              OPAIPS                               False
# ...

# %%
#Question 6:

Data Frame and Panel both are mutable in pyhton. DataFrame are General 2D labeled, size-mutable tabularstructure with potentially heterogeneously typedcolumns.
Panel are General 3D labeled, size-mutable array.

# %%
#Question 7:

courses = pd.Series(['Spark','Hadoop','Python'])
fees = pd.Series([2000,3000,2500])
discount = pd.Series([100,400,200])

df = pd.concat([courses, fees, discount],axis = 1)

# %%
df
# Out:
#         0     1    2
# 0   Spark  2000  100
# 1  Hadoop  3000  400
# 2  Python  2500  200

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
